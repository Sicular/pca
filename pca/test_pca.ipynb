# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
input = np.array([[1,1],[1,-1],[-1,1],[-1,-1]])

line = np.array([[-1,1], [-1,1]])
line1 = np.array([[-1,1], [-0.5,0.5]])

# %%
plt.scatter(input[:,0],input[:,1])
plt.plot(line[0], line[1], 'r-')
plt.plot(line1[0], line1[1], 'g-')

# %%
np.var(input.dot(line[1]))
# Out:
# 2.0

# %%
input @ line / (np.linalg.norm(line) ** 2) @ line
# Out:
# array([[0., 0.],
#        [0., 0.],
#        [0., 0.],
#        [0., 0.]])

# %%
np.var(input.dot(line1))
# Out:
# 1.25

# %%
np.var(input)
# Out:
# 1.0

# %%
input = np.array([
    [2.98028492, -0.69132151, 3.23844269],
    [9.13817914, -1.17076687, -1.17068478],
    [9.47527689, 3.83717365, -2.34737193],
    [3.25536026, -2.31708846, -2.32864877],
    [1.45177363, -9.56640122, -8.62458916],
])

# %%
input = input.T

# %%
fig = plt.figure()

# Plot the ellipse with zorder=0 in order to demonstrate
# its transparency (caused by the use of alpha).
ax = fig.add_subplot(projection="3d")
ax.scatter(input[:,0], input[:,1], input[:,2], s='0.5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-765eaecac8e4> in <module>
#       4 # its transparency (caused by the use of alpha).
#       5 ax = fig.add_subplot(projection="3d")
# ----> 6 ax.scatter(input[:,0], input[:,1], input[:,2], s='0.5')
#
# ~/anaconda3/lib/python3.8/site-packages/mpl_toolkits/mplot3d/axes3d.py in scatter(self, xs, ys, zs, zdir, s, c, depthshade, *args, **kwargs)
#    2310             zs = zs.copy()
#    2311
# -> 2312         patches = super().scatter(xs, ys, s=s, c=c, *args, **kwargs)
#    2313         art3d.patch_collection_2d_to_3d(patches, zs=zs, zdir=zdir,
#    2314                                         depthshade=depthshade)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# ...
